# %% [markdown]
# ### OOP ###

# %% [markdown]
# constructor

# %%
class Fraction:
    
    def __init__(self, top, bottom):
        self.num = top
        self.den = bottom

# %%
myfraction = Fraction(3,5)
print(myfraction)
# Out:
# <__main__.Fraction object at 0x0000000004DB6940>

# %% [markdown]
# \__str__ method for print

# %%
class Fraction:
    
    def __init__(self, top, bottom):
        self.num = top
        self.den = bottom
    
    def __str__(self):
        return str(self.num) + '/' + str(self.den)

# %%
myfraction = Fraction(3,5)
print(myfraction)
# Out:
# 3/5

# %% [markdown]
# arithmetic operations
# the addition method in python (f1+f2) is implemented as f1.\__add__(f2)

# %%
class Fraction:
    
    def __init__(self, top, bottom):
        self.num = top
        self.den = bottom
    
    def __str__(self):
        return str(self.num) + '/' + str(self.den)
    
    def __add__(self, otherfraction):
        newnum = self.num * otherfraction.den + self.den * otherfraction.num
        newden = self.den * otherfraction.den
#         return a new object
        return Fraction(newnum, newden)

# %%
f1 = Fraction(1,4)
f2 = Fraction(1,2)
f3 = f1 + f2
print(f3)
# Out:
# 6/8

# %% [markdown]
# The calculation was right... however the result is not in the 'lowest terms' representation.
# Now we will implement the Euclid's Algorithm to find greatest common divisor, or GCD. Then we use GCD to divide both num and den.

# %%
def gcd(m, n):
#     as long as residue is not zero
    while m%n != 0:
        oldm = m
        oldn = n
        m = oldn
#         gcd as residual of m divided by n
        n = oldm%oldn
#         print(n, oldm, oldn)
    return n

print(gcd(20,10))
# Out:
# 10

# %%
class Fraction:
    
    def __init__(self, top, bottom):
        self.num = top
        self.den = bottom
    
    def __str__(self):
        return str(self.num) + '/' + str(self.den)
    
    def __add__(self, otherfraction):
        newnum = self.num * otherfraction.den + self.den * otherfraction.num
        newden = self.den * otherfraction.den
        comdiv = gcd(newnum, newden)
#         return a new object
#         // floor divide
        return Fraction(newnum//comdiv, newden//comdiv)

# %%
f1 = Fraction(1,4)
f2 = Fraction(1,2)
f3 = f1 + f2
print(f3)
# Out:
# 3/4

# %% [markdown]
# implement deep equality (same value, not same reference to a common class)

# %%
class Fraction:
    
    def __init__(self, top, bottom):
        self.num = top
        self.den = bottom
    
    def __str__(self):
        return str(self.num) + '/' + str(self.den)
    
    def __add__(self, otherfraction):
        newnum = self.num * otherfraction.den + self.den * otherfraction.num
        newden = self.den * otherfraction.den
        comdiv = gcd(newnum, newden)
#         return a new object
#         // floor divide
        return Fraction(newnum//comdiv, newden//comdiv)

    def __eq__(self, other):
        firstnum = self.num * other.den
        secondnum = other.num * self.den
        return firstnum == secondnum
    
x = Fraction(1,2)
y = Fraction(2,3)
print(x+y)
print(x == y)
# Out:
# 7/6
# False

# %% [markdown]
# #### Inheritance: Logic Gates and Circuits ####

# %% [markdown]
# <img src="http://interactivepython.org/runestone/static/pythonds/_images/circuit1.png">

# %% [markdown]
# We start with the most general representation of gate characteristic - LogicGate. Then next level of subclasses breaks the logic gates into two families, those that have one input line and those that have two.

# %% [markdown]
# <img src="http://interactivepython.org/runestone/static/pythonds/_images/gates.png">

# %%
class LogicGate:
    
    def __init__(self, n):
        self.label = n
        self.output = None
        
    def getLabel(self):
        return self.label
    
    def getOutput(self):
        self.output = self.performGateLogic()
        return self.output

# %% [markdown]
# LogicGate will not be called directly... Instead, the method will be further defined in subclasses

# %%
test_logicgate = LogicGate("L1")
test_logicgate.getOutput()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-643cf87a837f> in <module>()
#       1 test_logicgate = LogicGate("L1")
# ----> 2 test_logicgate.getOutput()
#
# <ipython-input-31-1f1d911feef7> in getOutput(self)
#       9
#      10     def getOutput(self):
# ---> 11         self.output = self.performGateLogic()
#      12         return self.output
#      13
#
# AttributeError: 'LogicGate' object has no attribute 'performGateLogic'

# %%
class UnaryGate(LogicGate):

    def __init__(self,n):
        LogicGate.__init__(self,n)

        self.pin = None

    def getPin(self):
        return int(input("Enter Pin input for gate "+ self.getLabel()+"-->"))

# %%
class BinaryGate(LogicGate):
    
    def __init__(self, n):
        LogicGate.__init__(self,n)
        
        self.pin = None
        
    def getPinA(self):
        return int(input("Enter Pin A input for gate " + self.getLabel() + "-->"))
    
    def getPinB(self):
        return int(input("Enter Pin B input for gate" + self.getLabel() + "-->"))

# %% [markdown]
# label should be string objects

# %%
test_binarygate = BinaryGate("1")

# %%
test_binarygate.getPinA()
# Out:
# Enter Pin A input for gate 1-->0
# 0

# %% [markdown]
# AndGate inherites BinaryGate,

# %%
class AndGate(BinaryGate):
    
    def __init__(self, n):
        BinaryGate.__init__(self, n)
            
    def performGateLogic(self):
        
        a = self.getPinA()
        b = self.getPinB()
        if a == 1 and b == 1:
            return 1
        else:
            return 0

# %%
g1 = AndGate("G1")
g1.getOutput()
# Out:
# Enter Pin A input for gate G1-->1
# Enter Pin B input for gateG1-->0
# 0

# %%
class OrGate(BinaryGate):
    
    def __init__(self, n):
        BinaryGate.__init__(self, n)
            
    def performGateLogic(self):
        
        a = self.getPinA()
        b = self.getPinB()
        if a == 1 or b == 1:
            return 1
        else:
            return 0
        
        
class OrGate(UnaryGate):
    
    def __init__(self, n):
        UnaryGate.__init__(self, n)
            
    def performGateLogic(self):
        
        a = self.getPin()
        if a == 1:
            return 0
        else:
            return 1
